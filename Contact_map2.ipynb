# %%
from biopandas.pdb import PandasPdb
from math import *
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
pdb1=PandasPdb().read_pdb('/home/ailon/Desktop/python_practice/PDBfile/1t46_STI_A.txt')
pdb1.df['ATOM'].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLY
# 1        ATOM            2                CA                  GLY
# 2        ATOM            3                 C                  GLY
# 3        ATOM            4                 O                  GLY
# 4        ATOM            5                 N                  ASN
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A             565            ...  22.652   20.382   20.682
# 1        A             565            ...  23.584   21.304   19.964
# 2        A             565            ...  22.927   22.199   18.919
# 3        A             565            ...  23.603   22.680   18.003
# 4        A             566            ...  21.622   22.442   19.061
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     26.37                                  N    NaN         0
# ...

# %%
print(len(pdb2))
# Out:
# 2381

# %%
pdb2=pdb1.df['ATOM']

# %%
pdb2['atom_name']=='CB'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2376    False
# 2377     True
# 2378    False
# 2379    False
# 2380    False
# Name: atom_name, Length: 2381, dtype: bool

# %%
pdb2[(pdb2['atom_name']=='CB')&(pdb2['alt_loc']!='B')|(pdb2['residue_name']=='GLY')&(pdb2['atom_name']=='CA')]
# Out:
#      record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 1           ATOM            2                CA                  GLY
# 8           ATOM            9                CB                  ASN
# 16          ATOM           17                CB                  ASN
# 24          ATOM           25                CB                  TYR
# 36          ATOM           37                CB                  VAL
# ...          ...          ...     ...       ...     ...          ...     ...
# 2349        ATOM         2350                CB                  SER
# 2355        ATOM         2356                CB                  GLU
# 2364        ATOM         2365                CB                  SER
# 2370        ATOM         2371                CB                  THR
# 2377        ATOM         2378                CB                  ASN
#
#      chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# ...

# %%
print(list(pdb3['residue_number']))
# Out:
# [565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 652, 652, 653, 654, 654, 655, 656, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 83
# ...

# %%
alist = [565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 652, 652, 653, 654, 654, 655, 656, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 861, 862, 863, 864, 864, 865, 866, 867, 868, 869, 870, 871, 872, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 900, 901, 902, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 925, 926, 927, 928, 929, 930, 931, 932, 933]
blist = [565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 861, 862, 863, 864, 865, 866, 867, 868, 869, 870, 871, 872, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 900, 901, 902, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 929, 930, 931, 932, 933]

for i in range(len(alist)):
    for j in range(i+1, len(alist)):
        if alist[i] == alist[j]:
            print (alist[i])
# Out:
# 652
# 654
# 677
# 773
# 788
# 864
# 925

# %%
pdb3=pdb2[(pdb2['atom_name']=='CB')|(pdb2['residue_name']=='GLY')&(pdb2['atom_name']=='CA')]

# %%
len(pdb3)
# Out:
# 304

# %%
pdb3.loc[:,['residue_name','residue_number','x_coord','y_coord','z_coord']]
pdb4=pdb3.loc[:,['residue_name','residue_number','x_coord','y_coord','z_coord']]

# %%
def euclidean_distance(x, y):
    return sqrt(sum(pow(a - b, 2) for a, b in zip(x, y)))

# %%
arr1=np.empty((len(pdb4), len(pdb4)))
for i in range(len(pdb4)):
    for j in range(len(pdb4)):
        residue_pair1_2=pdb4.iloc[i][['x_coord','y_coord','z_coord']].values
        residue_pair2_2=pdb4.iloc[j][['x_coord','y_coord','z_coord']].values
        arr1[i][j]=euclidean_distance(residue_pair1_2,residue_pair2_2)

# %%
plt.imshow(arr1,cmap='bone')

# %%
arr2=np.empty((len(pdb4), len(pdb4)))
for i in range(len(pdb4)):
    for j in range(len(pdb4)):
        if arr1[i][j]<=8:
            arr2[i][j]=1
        else:
            arr2[i][j]=0

# %%
plt.imshow(arr2,cmap='bone')
